# %%
from torch.utils.data import Dataset
class SalacyDataset(Dataset):
    def __init__(self,img_path,img_cls,transform) -> None:
        self.images_path = img_path
        img_cls = img_path
        self.images_class = img_cls 
        self.transform = transform
    def __getitem__(self, index) :
        pass
    def __len__():
        pass

# %%
import os
path = r'D:\data\animals_catalogy\salicon\images'
list(os.walk(path))###这种每一个都是递归的文件  第一个是根目录 第二个是当前文件夹下的子目录 ， 第三个是当前文件夹下的内容
def lab_img_path(path):
    pass
    for i in os.walk(path):
        print(i)
lab_img_path(path=path)
# Out:
# ('D:\\data\\animals_catalogy\\salicon\\images', ['test', 'train', 'val'], [])
# ...
